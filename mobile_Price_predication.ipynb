# %% [markdown]
# <a href="https://colab.research.google.com/github/varun-varada/Machine_learning-1/blob/main/mobile_Price_predication.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.pipeline import Pipeline

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler

# %%
data=pd.read_csv("dataset.csv")
data
# Out:
#       battery_power  blue  clock_speed  dual_sim  ...  three_g  touch_screen  wifi  price_range
# 0               842     0          2.2         0  ...        0             0     1            1
# 1              1021     1          0.5         1  ...        1             1     0            2
# 2               563     1          0.5         1  ...        1             1     0            2
# 3               615     1          2.5         0  ...        1             0     0            2
# 4              1821     1          1.2         0  ...        1             1     0            1
# ...             ...   ...          ...       ...  ...      ...           ...   ...          ...
# 1995            794     1          0.5         1  ...        1             1     0            0
# 1996           1965     1          2.6         1  ...        1             1     1            2
# 1997           1911     0          0.9         1  ...        1             1     0            3
# ...

# %%
# pd.set_option('max_columns',None)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
Y=data['price_range'].copy()
X=data.drop('price_range',axis=1).copy()

# %%
X_train,x_test,y_train,y_test=train_test_split(X,Y,train_size=0.7,random_state=20)

# %%
pipe=Pipeline([('scalar',StandardScaler()),('logistic_regression',LogisticRegression())])

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('scalar', StandardScaler()),
#                 ('logistic_regression', LogisticRegression())])

# %%
print("Accurarcy",pipe.score(x_test,y_test))
# Out:
# Accurarcy 0.9483333333333334

# %% [markdown]
#  This model assesses the accuracy of the dataset.
